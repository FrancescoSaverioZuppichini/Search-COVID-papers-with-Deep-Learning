# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Search COVID papers with Deep Learning
# *Transformers + Elastic Search = ❤️*
#
# Good news everyone! In this article, we are not going to fit a linear regression on the sars-cov-19 data. Rather, we will do something more interesting. Most of the work is based on [this project](https://github.com/gsarti/covid-papers-browser) in which I am working with students from the Universita of Triest (Italy). A live demo is available TODO

# %% [markdown]
# ## Data
#
# We are going to use this dataset from Kaggle, we only need the `metadata.csv` file that contains information about the paper and the full text of the abstract. Let's take a look!

# %%
import pandas as pd
from Project import Project
# Project holds all the path
pr = Project()

df = pd.read_csv(pr.data_dir / 'metadata.csv')

df.head(1)
# Out:
#    cord_uid                                       sha source_x  \
# 0  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
#
#                                                title  \
# 0  Sequence requirements for RNA strand transfer ...
#
#                         doi      pmcid   pubmed_id license  \
# 0  10.1093/emboj/20.24.7220  PMC125340  11742998.0     unk
#
#                                             abstract publish_time  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
#
#                                              authors           journal  \
# 0  Pasternak, Alexander O.; van den Born, Erwin; ...  The EMBO Journal
#
#    Microsoft Academic Paper ID WHO #Covidence  has_pdf_parse  \
# 0                          NaN            NaN           True
#
#    has_pmc_xml_parse  full_text_file  \
# 0               True  custom_license
#
#                                                  url
# 0  http://europepmc.org/articles/pmc125340?pdf=re...

# %%
df['pubmed_id'] = df['pubmed_id']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57366 entries, 0 to 57365
# Data columns (total 18 columns):
# cord_uid                       57366 non-null object
# sha                            43540 non-null object
# source_x                       57366 non-null object
# title                          57203 non-null object
# doi                            54020 non-null object
# pmcid                          46804 non-null object
# pubmed_id                      40905 non-null float64
# license                        57366 non-null object
# abstract                       46847 non-null object
# publish_time                   57358 non-null object
# authors                        54840 non-null object
# journal                        51576 non-null object
# Microsoft Academic Paper ID    964 non-null float64
# WHO #Covidence                 1768 non-null object
# has_pdf_parse                  57366 non-null bool
# has_pmc_xml_parse              57366 non-null bool
# full_text_file                 48921 non-null object
# url                            57060 non-null object
# dtypes: bool(2), float64(2), object(14)
# memory usage: 7.1+ MB

# %% [markdown]
# Let's create a `Dataset` to properly work with the data in the pytorch enviroment. To give our search engine more context, we will embed the `title` and the `abstract` together, this is sotred in the `title_abstract` key.

# %%
from torch.utils.data import Dataset, DataLoader

class CovidPapersDataset(Dataset):    
    def __init__(self, df, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.df = df
        self.df = self.df[['title', 'authors', 'abstract', 'url', 'pubmed_id', ]]
        self.df.title.fillna('', inplace = True)
        self.df.abstract.fillna('', inplace = True)
        self.df = self.df.fillna(0)
    def __getitem__(self, idx):
        row = self.df.loc[idx]
        self.df.loc[idx:, 'title_abstract'] = f"{row['title']} {row['abstract']}"
        return  self.df.loc[idx].to_dict()

    def __len__(self):
        return self.df.shape[0]
    
    @classmethod
    def from_path(cls, path, *args, **kwargs):
        df = pd.read_csv(path)
        return cls(df=df, *args, **kwargs)

# %% [markdown]
# In order, I have subclassed `torch.utils.data.Dataset` to create a custom dataset. The dataset is expecting a dataframe as input, we keep only the interesting columns as input and filling up the nans.
#
# We return a dictionary since the dataframe is not a support type in pytorch. We can test it out

# %%
ds = CovidPapersDataset.from_path(pr.data_dir / 'metadata.csv')

ds[0]['title']
# Out:
# 'Sequence requirements for RNA strand transfer during nidovirus discontinuous subgenomic RNA synthesis'

# %% [markdown]
# ## Embed
#
# Now we need a way to create an embedding from the data. We defined a class `Embedder` that loads automatically a model from `hugging_faces`. On top of that we add a pooling layer to create one single `768` vector for each input.
#
# **TODO** Explain model choice

# %%
from dataclasses import dataclass
from sentence_transformers import models, SentenceTransformer

@dataclass
class Embedder:
    name: str = 'gsarti/scibert-nli'
    max_seq_length: int  = 128
    do_lower_case: bool  = True
    
    def __post_init__(self):
        word_embedding_model = models.BERT(
            'gsarti/biobert-nli',
            max_seq_length=128,
            do_lower_case=True
        )
        pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(),
                pooling_mode_mean_tokens=True,
                pooling_mode_cls_token=False,
                pooling_mode_max_tokens=False
            )
    
        self.model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
        
    def __call__(self, text):
        return self.model.encode(text)

# %% [markdown]
# Let's try it by embedding a data point in our dataset

# %%
embedder = Embedder()

emb = embedder(ds[0]['title_abstract'])

emb[0].shape
# Out:
# (768,)

# %% [markdown]
# Et voilà!

# %% [markdown]
# We can now create a Dataloader to process our papers in batch.

# %% [markdown]
# ## Search
#
# Okay, we now have a way to embed each paper, but how can we search in the data using a query? Assuming we have embedded **all** the papers we could also **embed the query** and compute the cosine similarity between the query and all the embedding and then show the results sorted by the distance. Intuitively, the closer the more similar.
#
# So, how we can do it? We need a proper way to handle the data and to run the cosine similarity fast enough. Fortunately, Elastic Search comes to the rescue!
#
# ### Elastic Search
#
# [Elastic Search](https://www.elastic.co/) is a database with one goal, yes you guessed right: searching. We will first store all the embedding in elastic and then use its API to perform the searching. If you are lazy like me you can [install elastic search with docker](https://www.elastic.co/guide/en/elasticsearch/reference/current/docker.html)
#
# ```
# docker pull docker.elastic.co/elasticsearch/elasticsearch:7.6.2
# docker run -p 9200:9200 -p 9300:9300 -e "discovery.type=single-node" docker.elastic.co/elasticsearch/elasticsearch:7.6.2
#
# ```
#
# Perfect. The next step is to store the embeddings and the papers' information on elastic search. It is a very straightforward process. We first need to create an `index` (a new database) and then to create one entry for each paper.
#
# When we create an `index` we need to describe for elastic what we wish to store. In our case:
#
#
# ```
# {
#     "settings": {
#         "number_of_shards": 2,
#         "number_of_replicas": 1
#     },
#     "mappings": {
#         "dynamic": "true",
#         "_source": {
#             "enabled": "true"
#         },
#         "properties": {
#             "title": {
#                 "type": "text"
#             },
#             ... all other properties (columns of the datafarme)
#             "embed": {
#                 "type": "dense_vector",
#                 "dims": 768
#             }
#         }
#     }
# }
#
# ```
#
# The last entry we define a property `embed` as a dense vector with `768`. This is indeed our embed.

# %%
from dataclasses import dataclass, field
from pathlib import Path
from elasticsearch import Elasticsearch
from tqdm.autonotebook import tqdm
import pandas as pd
import json
from elasticsearch.helpers import bulk

@dataclass
class ElasticSearchProvider:
    index_file: dict
    client: Elasticsearch = Elasticsearch()
    index_name: str = 'covid'

    def drop(self):
        self.client.indices.delete(index=self.index_name, ignore=[404])
        return self

    def create_index(self):
        self.client.indices.create(index=self.index_name, body=self.index_file)
        return self

    def create_and_bulk_documents(self, entries:list):
        entries_elastic = []
        for entry in entries:
            entry_elastic = {
                **entry,
                **{
                    '_op_type': 'index',
                    '_index': self.index_name
                }
            }
        
            entries_elastic.append(entry_elastic)
            
        bulk(self.client, entries_elastic)

    def __call__(self, entries: list):
        self.create_and_bulk_documents(entries)

        return self

# %% [markdown]
# Unfortunatly, Elastic Search won't be able to serialize the `numpy` arrays. So we need to create an Adapter for our data. This class takes a list and "adapt" the data to work in our `ElasticSearchProvider`.

# %%
class CovidPapersEmbeddedAdapter:
        
    def __call__(self, x, embs):
        for el, emb in zip(x, embs):
            el['embed'] = np.array(emb).tolist()

        return x

# %% [markdown]
# Okay, we have everything in place. A way to represent the date, one to encode them in a vector and a way to store the result. Let's wrap

# %%
dl = DataLoader(ds, batch_size=128, num_workers=4, collate_fn=lambda x: x)
es_adapter = CovidPapersEmbeddedAdapter()

import numpy as np
from utils import device



with open(pr.base_dir / 'es_index.json', 'r') as f:
    index_file = json.load(f)
    es_provider = ElasticSearchProvider(index_file)

es_provider.drop()
es_provider.create_index()

for batch in tqdm(dl):
    x = [b['title_abstract'] for b in batch]
    embs = embedder(x)
    es_provider(es_adapter(batch, embs))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=449.0), HTML(value='')))

# %% [markdown]
# If we now go take a look at `http://localhost:9200/covid/_search?pretty=true&q=*:*` We will see our data correctly stored on elastic search

# %% [markdown]
# ### Make a query
#
# We are almost done. The last piece of the puzzle is a way to search in the database. Elastic search can perform cosine similarity between one input vector and a target vector field in all the documents. The syntax is very easy:
#
# ```
#  {
#     "query": {
#         "match_all": {}
#     },
#     "script": {
#         "source":
#         "cosineSimilarity(params.query_vector, doc['embed']) + 1.0",
#         "params": {
#             "query_vector": vector
#         }
#     }
# }
#
# ```
#
# Where `vector` is our input. So, we define a class that does exactly that, takes an vector as an input an show all the results from the query

# %%
@dataclass
class Elasticsearcher:
    """
    This class implements the logic behind searching for a vector in elastic search.
    """
    client: Elasticsearch = Elasticsearch()
    index_name: str = 'covid'

    def __call__(self, vector: list):
        script_query = {
            "script_score": {
                "query": {
                    "match_all": {}
                },
                "script": {
                    "source":
                    "cosineSimilarity(params.query_vector, doc['embed']) + 1.0",
                    "params": {
                        "query_vector": vector
                    }
                }
            }
        }

        res = self.client.search(
            index=self.index_name,
            body={
                "size": 1000,
                "query": script_query,
                "_source": {
                    "includes": ["title", "abstract"]
                }
            })

        return res

# %%
es_search = Elasticsearcher()
es_search(embedder('covid syntopms')[0].tolist())
# Out:
# {'took': 270,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.8080369,
#   'hits': [{'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Phn1sXEBuCitufzF0m8L',
#     '_score': 1.8080369,
#     '_source': {'abstract': 0, 'title': 'TOC'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ehn4sXEBuCitufzFbr3k',
#     '_score': 1.8080369,
#     '_source': {'abstract': 0, 'title': 'TOC'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vxn4sXEBuCitufzF7stI',
#     '_score': 1.8080369,
#     '_source': {'abstract': 0, 'title': 'TOC'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'YBn1sXEBuCitufzFBlFH',
#     '_score': 1.8077158,
#     '_source': {'abstract': 0, 'title': 'References'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ixn3sXEBuCitufzFgaEk',
#     '_score': 1.8077158,
#     '_source': {'abstract': 0, 'title': 'References'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-hn3sXEBuCitufzFApK-',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'IRn3sXEBuCitufzFFJVU',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Pxn3sXEBuCitufzFTJsT',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hhn3sXEBuCitufzFB5Mt',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'iRn4sXEBuCitufzFYrt0',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'thn4sXEBuCitufzFocKk',
#     '_score': 1.8055282,
#     '_source': {'abstract': 0, 'title': 'Commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hRn1sXEBuCitufzFDVJ2',
#     '_score': 1.8054094,
#     '_source': {'abstract': 0, 'title': 'Reply'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn4sXEBuCitufzFncKr',
#     '_score': 1.7927966,
#     '_source': {'abstract': 0, 'title': 'Corrections'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Vhn3sXEBuCitufzFgaEk',
#     '_score': 1.7927966,
#     '_source': {'abstract': 0, 'title': 'Corrections'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8hn3sXEBuCitufzFwqhX',
#     '_score': 1.7927966,
#     '_source': {'abstract': 0, 'title': 'Corrections'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '7Bn4sXEBuCitufzFRLd3',
#     '_score': 1.7927966,
#     '_source': {'abstract': 0, 'title': 'Corrections'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6Bn2sXEBuCitufzF2o0T',
#     '_score': 1.788665,
#     '_source': {'abstract': 0, 'title': 'Errata'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'BBnzsXEBuCitufzFHx90',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'Correction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'BRnzsXEBuCitufzFHx90',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'Correction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rRn1sXEBuCitufzFEFLv',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'Correction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rRn1sXEBuCitufzFV1va',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'CORRECTION'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '5hn3sXEBuCitufzF_69E',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'Correction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zxn4sXEBuCitufzFarzg',
#     '_score': 1.784486,
#     '_source': {'abstract': 0, 'title': 'Correction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ZhnzsXEBuCitufzFhyo2',
#     '_score': 1.78422,
#     '_source': {'abstract': 0, 'title': 'Reply to Oh'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zhn3sXEBuCitufzFUJve',
#     '_score': 1.7830361,
#     '_source': {'abstract': 0, 'title': "What's in this issue"}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Dhn1sXEBuCitufzF1HAs',
#     '_score': 1.7827774,
#     '_source': {'abstract': 0, 'title': 'Highlights'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ohn2sXEBuCitufzF2455',
#     '_score': 1.7827774,
#     '_source': {'abstract': 0, 'title': 'Highlights'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lhn2sXEBuCitufzF2455',
#     '_score': 1.7827773,
#     '_source': {'abstract': 0, 'title': 'Highlights'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6Bn2sXEBuCitufzF8ZB6',
#     '_score': 1.7823255,
#     '_source': {'abstract': 0, 'title': 'In reply:'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nBn4sXEBuCitufzFL7Wg',
#     '_score': 1.7823255,
#     '_source': {'abstract': 0, 'title': 'In reply:'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jBn1sXEBuCitufzF1nCu',
#     '_score': 1.7818326,
#     '_source': {'abstract': 0, 'title': 'Comment'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Kxn4sXEBuCitufzF8syQ',
#     '_score': 1.7818326,
#     '_source': {'abstract': 0, 'title': 'Comment'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xxn4sXEBuCitufzFw8bJ',
#     '_score': 1.7804389,
#     '_source': {'abstract': 0, 'title': "What's news"}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '2hn1sXEBuCitufzFxGxF',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'GBn1sXEBuCitufzF43OW',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Dhn1sXEBuCitufzF9XbF',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oRn2sXEBuCitufzF2455',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Rhn1sXEBuCitufzFx20H',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ghn1sXEBuCitufzF8nWv',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KBn2sXEBuCitufzF2455',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Whn2sXEBuCitufzF2455',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dhn2sXEBuCitufzF2455',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ghn2sXEBuCitufzF2455',
#     '_score': 1.7781929,
#     '_source': {'abstract': 0, 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hRn2sXEBuCitufzFq4gD',
#     '_score': 1.777325,
#     '_source': {'abstract': 0, 'title': 'A SARS commentary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3Bn1sXEBuCitufzFz24J',
#     '_score': 1.7756265,
#     '_source': {'abstract': 0, 'title': 'Issue highlights'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'kRn1sXEBuCitufzFQFg_',
#     '_score': 1.7748204,
#     '_source': {'abstract': 0, 'title': '& Management'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Fhn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Fxn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'GBn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Gxn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'HRn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'FRn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'GRn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ghn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'HBn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Hhn1sXEBuCitufzFv2yI',
#     '_score': 1.7672648,
#     '_source': {'abstract': 0, 'title': 'ISAR News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Fhn1sXEBuCitufzF6HSq',
#     '_score': 1.767007,
#     '_source': {'abstract': 0, 'title': 'Thank you'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nBn1sXEBuCitufzFBlFH',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rBn1sXEBuCitufzFCVHN',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'tRn1sXEBuCitufzFCVHN',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yhn1sXEBuCitufzFCVHN',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oBn1sXEBuCitufzFBlFH',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Xxn3sXEBuCitufzFm6QK',
#     '_score': 1.7666676,
#     '_source': {'abstract': 0, 'title': 'In Brief'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'JRn0sXEBuCitufzF9U9U',
#     '_score': 1.7659348,
#     '_source': {'abstract': 0, 'title': 'Truth in the Details'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bhn2sXEBuCitufzF_pJ6',
#     '_score': 1.7628111,
#     '_source': {'abstract': 0, 'title': 'Avant-Propos'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xhn1sXEBuCitufzFCVHN',
#     '_score': 1.7624571,
#     '_source': {'abstract': 0, 'title': 'In this issue'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8hn2sXEBuCitufzF2o0T',
#     '_score': 1.762457,
#     '_source': {'abstract': 0, 'title': 'In this issue'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9Rn2sXEBuCitufzF2o0T',
#     '_score': 1.762457,
#     '_source': {'abstract': 0, 'title': 'In this issue'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'tRn1sXEBuCitufzFEFLv',
#     '_score': 1.762457,
#     '_source': {'abstract': 0, 'title': 'IN THIS ISSUE'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KRn2sXEBuCitufzF2455',
#     '_score': 1.7623466,
#     '_source': {'abstract': 0, 'title': 'SARS art'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nxn1sXEBuCitufzFt2py',
#     '_score': 1.7600377,
#     '_source': {'abstract': 0, 'title': 'Issue TOC'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oBn1sXEBuCitufzFt2py',
#     '_score': 1.7600377,
#     '_source': {'abstract': 0, 'title': 'Issue TOC'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xRn3sXEBuCitufzFSJoP',
#     '_score': 1.7595435,
#     '_source': {'abstract': 0, 'title': 'Conclusion'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'IBn1sXEBuCitufzFyW78',
#     '_score': 1.7589287,
#     '_source': {'abstract': 0, 'title': 'Actualités'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'IRn1sXEBuCitufzFyW78',
#     '_score': 1.7589287,
#     '_source': {'abstract': 0, 'title': 'Actualités'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn1sXEBuCitufzFx20H',
#     '_score': 1.7586324,
#     '_source': {'abstract': 0, 'title': 'Feedback'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'gBn1sXEBuCitufzFx20H',
#     '_score': 1.7586324,
#     '_source': {'abstract': 0, 'title': 'Feedback'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'qxn3sXEBuCitufzFC5OJ',
#     '_score': 1.7586324,
#     '_source': {'abstract': 0, 'title': 'Feedback'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'shn3sXEBuCitufzFLZe3',
#     '_score': 1.7586324,
#     '_source': {'abstract': 0, 'title': 'Feedback'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Uxn3sXEBuCitufzFeKCp',
#     '_score': 1.7586324,
#     '_source': {'abstract': 0, 'title': 'Feedback'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ihn0sXEBuCitufzF8E9w',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'NEWS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dhn1sXEBuCitufzFTVrb',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'IBn0sXEBuCitufzF8E9w',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'NEWS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cBn1sXEBuCitufzFDVJ2',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'qRn1sXEBuCitufzFEFLv',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'qhn1sXEBuCitufzFEFLv',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zxn1sXEBuCitufzFEFLv',
#     '_score': 1.7575791,
#     '_source': {'abstract': 0, 'title': 'News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jRn1sXEBuCitufzFU1vj',
#     '_score': 1.75713,
#     '_source': {'abstract': 0, 'title': 'Issue Information'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Xxn2sXEBuCitufzFdIKh',
#     '_score': 1.75713,
#     '_source': {'abstract': 0, 'title': 'Issue Information'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'DRn4sXEBuCitufzFGbMi',
#     '_score': 1.7544589,
#     '_source': {'abstract': 0, 'title': '84 Ethics'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Vxn2sXEBuCitufzF2455',
#     '_score': 1.7539952,
#     '_source': {'abstract': 0, 'title': 'SARS revisited'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Gxn2sXEBuCitufzFuIos',
#     '_score': 1.7511679,
#     '_source': {'abstract': 0, 'title': 'SARS revisited.'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jhn1sXEBuCitufzFm2Qq',
#     '_score': 1.7511623,
#     '_source': {'abstract': 0, 'title': 'Literature'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fRn1sXEBuCitufzF8nWv',
#     '_score': 1.7475097,
#     '_source': {'abstract': 0, 'title': 'Forthcoming topics'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'wRn4sXEBuCitufzFXrpg',
#     '_score': 1.7470874,
#     '_source': {'abstract': 0, 'title': 'MERS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yRn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4Bn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4hn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6Bn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '7xn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'HRn1sXEBuCitufzFoWbn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Hhn1sXEBuCitufzFoWbn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Phn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SBn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'WBn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'XRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Yhn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'eRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'gRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ihn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jhn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vBn1sXEBuCitufzFp2bb',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Bn1sXEBuCitufzFp2bb',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Mhn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'URn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Vhn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Vxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'XBn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Xxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ZRn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'kxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lRn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lhn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mBn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rBn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8Rn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9xn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-Rn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-hn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Exn1sXEBuCitufzFq2i0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'MRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Mxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'PBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'YBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Yxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'axn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'eBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ehn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'gBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'gxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ihn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'kRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'thn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xRn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yRn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yhn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '2xn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '5Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '5xn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9xn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-Bn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'wxn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xhn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xxn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yhn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yxn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6hn1sXEBuCitufzFoWXn',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KBn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ohn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Rxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Xhn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Yxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'exn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fRn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fhn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'gxn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hhn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ixn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jBn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nBn1sXEBuCitufzFpGa_',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'uxn1sXEBuCitufzFp2bb',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vxn1sXEBuCitufzFp2bb',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Rn1sXEBuCitufzFp2bb',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Txn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'WBn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'WRn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Whn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Wxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'YRn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Yxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zhn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'aRn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lBn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oBn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oxn1sXEBuCitufzFqmcy',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rhn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '1xn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '7xn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8xn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9Rn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-Bn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Rn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_xn1sXEBuCitufzFq2e0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'FBn1sXEBuCitufzFq2i0',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'MBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Rhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Xxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Yhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'aRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bhn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'chn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'eRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'exn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lxn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nBn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nRn1sXEBuCitufzFrGj9',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'pBn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zBn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zxn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '0Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '2Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3Bn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3hn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3xn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9Rn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-hn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-xn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Bn1sXEBuCitufzFr2gq',
#     '_score': 1.74688,
#     '_source': {'abstract': 'Unknown', 'title': 0}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cxn4sXEBuCitufzFQLdA',
#     '_score': 1.7453283,
#     '_source': {'abstract': 0, 'title': 'Exceptional matters'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Uxn3sXEBuCitufzFgaEk',
#     '_score': 1.7438107,
#     '_source': {'abstract': 0, 'title': 'WHO is SARS?'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'RRn1sXEBuCitufzF63TO',
#     '_score': 1.7434441,
#     '_source': {'abstract': 0, 'title': 'Acronyms'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'PBn1sXEBuCitufzF5nMc',
#     '_score': 1.7431562,
#     '_source': {'abstract': 0, 'title': "Authors' reply"}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '3xn1sXEBuCitufzFUVol',
#     '_score': 1.7431562,
#     '_source': {'abstract': 0, 'title': "Authors' reply"}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Uhn1sXEBuCitufzF63TO',
#     '_score': 1.7423433,
#     '_source': {'abstract': 0, 'title': 'Glossary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jxn1sXEBuCitufzFBlFH',
#     '_score': 1.742322,
#     '_source': {'abstract': 0, 'title': 'In the news'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mRn1sXEBuCitufzFBlFH',
#     '_score': 1.742322,
#     '_source': {'abstract': 0, 'title': 'In the News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mxn1sXEBuCitufzFBlFH',
#     '_score': 1.742322,
#     '_source': {'abstract': 0, 'title': 'In the News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oRn1sXEBuCitufzFBlFH',
#     '_score': 1.742322,
#     '_source': {'abstract': 0, 'title': 'In the News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'pxn1sXEBuCitufzFCVHN',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'txn1sXEBuCitufzFCVHN',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the news'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8hn1sXEBuCitufzFv2uI',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the news'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'pRn1sXEBuCitufzFCVHN',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the news'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vBn1sXEBuCitufzFCVHN',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the news'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'xRn1sXEBuCitufzFCVHN',
#     '_score': 1.7423218,
#     '_source': {'abstract': 0, 'title': 'In the News'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Lhn3sXEBuCitufzFTJsT',
#     '_score': 1.7408152,
#     '_source': {'abstract': 0, 'title': 'Response'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nRn3sXEBuCitufzFgaEk',
#     '_score': 1.7408152,
#     '_source': {'abstract': 0, 'title': 'Response'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '1hn4sXEBuCitufzF9sz1',
#     '_score': 1.7408152,
#     '_source': {'abstract': 0, 'title': 'Response'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'yRn1sXEBuCitufzFp2bb',
#     '_score': 1.7400949,
#     '_source': {'abstract': 'Unknown', 'title': 'Contents of Volume I'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zRn1sXEBuCitufzF73RC',
#     '_score': 1.7400744,
#     '_source': {'abstract': 0, 'title': 'Discussion'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vBn2sXEBuCitufzFgoOz',
#     '_score': 1.73639,
#     '_source': {'abstract': 0, 'title': 'Authors’ reply'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Vhn3sXEBuCitufzFtacT',
#     '_score': 1.7355087,
#     '_source': {'abstract': 0, 'title': 'Summaries'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Thn4sXEBuCitufzFUblK',
#     '_score': 1.7355087,
#     '_source': {'abstract': 0, 'title': 'Summaries'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'PxjxsXEBuCitufzFdfc7',
#     '_score': 1.7341315,
#     '_source': {'abstract': 0, 'title': 'SARS Alert Applicability'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Phn1sXEBuCitufzFQFg_',
#     '_score': 1.731012,
#     '_source': {'abstract': 0, 'title': 'China'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'hRn3sXEBuCitufzFKZdr',
#     '_score': 1.7307676,
#     '_source': {'abstract': 0, 'title': 'Issues for reporting results'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jhnzsXEBuCitufzFfimx',
#     '_score': 1.7289387,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mRn1sXEBuCitufzFl2Nm',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oRn1sXEBuCitufzFn2Wo',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'thn1sXEBuCitufzF2XBE',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9hn2sXEBuCitufzF2o0T',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'uRn3sXEBuCitufzFjqIv',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'CBn1sXEBuCitufzF73VC',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SBn4sXEBuCitufzF8syQ',
#     '_score': 1.7289386,
#     '_source': {'abstract': 0, 'title': 'Erratum'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jhn1sXEBuCitufzF1nCu',
#     '_score': 1.7285857,
#     '_source': {'abstract': 0, 'title': 'Events'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'DRn1sXEBuCitufzF3nL-',
#     '_score': 1.7285856,
#     '_source': {'abstract': 0, 'title': 'Events'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'MRn1sXEBuCitufzF4XIe',
#     '_score': 1.7285856,
#     '_source': {'abstract': 0, 'title': 'Events'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Rhn1sXEBuCitufzFqmcy',
#     '_score': 1.7273446,
#     '_source': {'abstract': 'Unknown', 'title': 'Overview'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '7Bn2sXEBuCitufzFuIks',
#     '_score': 1.7273097,
#     '_source': {'abstract': 0, 'title': 'Witnesses'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'BRn3sXEBuCitufzFJZcM',
#     '_score': 1.7271463,
#     '_source': {'abstract': 0, 'title': 'Subject index*'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fBn1sXEBuCitufzFU1vj',
#     '_score': 1.7267623,
#     '_source': {'abstract': 0, 'title': 'Reflections on SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'mBn3sXEBuCitufzFKZdr',
#     '_score': 1.7267623,
#     '_source': {'abstract': 0, 'title': 'Reflections on SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'whn4sXEBuCitufzFqsMj',
#     '_score': 1.7262716,
#     '_source': {'abstract': 0, 'title': 'Differential Diagnosis'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4Bn3sXEBuCitufzF9q6i',
#     '_score': 1.7236054,
#     '_source': {'abstract': 0, 'title': 'Législation'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8xnzsXEBuCitufzFcScU',
#     '_score': 1.7230794,
#     '_source': {'abstract': 0, 'title': 'Focus: SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'MBn1sXEBuCitufzFsmlA',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'Éditorial'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '7Bn1sXEBuCitufzF3nH-',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'Éditorial'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'iRnzsXEBuCitufzF7DUg',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'EDITORIAL'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'sBn1sXEBuCitufzFQ1go',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'Éditorial'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Dhn1sXEBuCitufzF_Hca',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'Éditorial'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Rn3sXEBuCitufzFn6Q4',
#     '_score': 1.7229427,
#     '_source': {'abstract': 0, 'title': 'Éditorial'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'BRn1sXEBuCitufzF1HAs',
#     '_score': 1.7211891,
#     '_source': {'abstract': 0, 'title': 'Cumulative Contents'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8xn1sXEBuCitufzFv2uI',
#     '_score': 1.721189,
#     '_source': {'abstract': 0, 'title': 'Cumulative Contents'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'VRnzsXEBuCitufzFfimx',
#     '_score': 1.7211285,
#     '_source': {'abstract': 0, 'title': 'Reply to Leow'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fhn1sXEBuCitufzF8nWv',
#     '_score': 1.7210015,
#     '_source': {'abstract': 0, 'title': 'Forthcoming Articles'}},
# ...
#     '_source': {'abstract': 0, 'title': 'Time to show unity against SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Ohn4sXEBuCitufzFL7Wg',
#     '_score': 1.6012765,
#     '_source': {'abstract': 0, 'title': 'The limits of techne and episteme'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ihn1sXEBuCitufzFwWz8',
#     '_score': 1.6011608,
#     '_source': {'abstract': 0, 'title': 'I. Sachverzeichnis'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'FBn1sXEBuCitufzF3nL-',
#     '_score': 1.6007072,
#     '_source': {'abstract': 0, 'title': 'Threatwatch'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'wBn3sXEBuCitufzFhaFn',
#     '_score': 1.6006082,
#     '_source': {'abstract': 0, 'title': 'Diary'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zhn1sXEBuCitufzFBlFH',
#     '_score': 1.6005676,
#     '_source': {'abstract': 0, 'title': 'Living with viruses'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'pRn2sXEBuCitufzFuIks',
#     '_score': 1.6003816,
#     '_source': {'abstract': 0, 'title': 'Editorial freedom in Focus.'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'GBn1sXEBuCitufzFr2kq',
#     '_score': 1.6001788,
#     '_source': {'abstract': 0, 'title': 'Subject index—volume 117'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6xn3sXEBuCitufzFJZYM',
#     '_score': 1.6000319,
#     '_source': {'abstract': 0, 'title': 'Disease X and other unknowns'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bxn1sXEBuCitufzFm2Qq',
#     '_score': 1.5999664,
#     '_source': {'abstract': 0, 'title': 'Contents of volume 25'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KBn1sXEBuCitufzFm2Qq',
#     '_score': 1.5999663,
#     '_source': {'abstract': 0, 'title': 'Contents of volume 25'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lBn1sXEBuCitufzFl2Nm',
#     '_score': 1.5998904,
#     '_source': {'abstract': 0, 'title': 'Subject index for volume 114'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn1sXEBuCitufzFsmlA',
#     '_score': 1.5998458,
#     '_source': {'abstract': 0, 'title': 'Subject Index: TO FOLLOW'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ehn1sXEBuCitufzFl2Nm',
#     '_score': 1.5995144,
#     '_source': {'abstract': 0, 'title': 'Subject index to volume 104'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cBn1sXEBuCitufzFt2py',
#     '_score': 1.5993154,
#     '_source': {'abstract': 0, 'title': 'AVTRW abstracts'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nxn0sXEBuCitufzFHzpE',
#     '_score': 1.5993114,
#     '_source': {'abstract': 0, 'title': 'Medicine and diplomacy'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dhn3sXEBuCitufzFrKaP',
#     '_score': 1.599038,
#     '_source': {'abstract': 0, 'title': 'Antimicrobials'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'BRn1sXEBuCitufzFX123',
#     '_score': 1.5989848,
#     '_source': {'abstract': 0, 'title': 'Nucleus and gene expression'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dhn3sXEBuCitufzF6a1S',
#     '_score': 1.5989339,
#     '_source': {'abstract': 0,
#      'title': 'INFECTION CONTROL AND BARRIER MATERIALS: AN OVERVIEW'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6hn1sXEBuCitufzF6HOq',
#     '_score': 1.5985034,
#     '_source': {'abstract': 0, 'title': 'EP News: Clinical'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Exn1sXEBuCitufzFv2yI',
#     '_score': 1.5984886,
#     '_source': {'abstract': 0, 'title': 'Contents of volume 77'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'cBn1sXEBuCitufzF23Gl',
#     '_score': 1.5983824,
#     '_source': {'abstract': 0, 'title': 'Test De Autoevaluación'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jBn2sXEBuCitufzF2455',
#     '_score': 1.5981396,
#     '_source': {'abstract': 0, 'title': 'The Back Pages'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Lhn4sXEBuCitufzFarzg',
#     '_score': 1.5980097,
#     '_source': {'abstract': 0, 'title': 'BODY RECOVERY'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-hn3sXEBuCitufzFwqhX',
#     '_score': 1.597916,
#     '_source': {'abstract': 0, 'title': '8 Safety Precautions'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4Rn1sXEBuCitufzFtGlT',
#     '_score': 1.5978194,
#     '_source': {'abstract': 0, 'title': 'Liquid column chromatography'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Zxn1sXEBuCitufzF1nCu',
#     '_score': 1.5978192,
#     '_source': {'abstract': 0,
#      'title': 'Graphical Abstract Contents Continued'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lxn4sXEBuCitufzFN7b7',
#     '_score': 1.5975335,
#     '_source': {'abstract': 0, 'title': 'Table of contents 2'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '0Rn3sXEBuCitufzFsKbj',
#     '_score': 1.5973839,
#     '_source': {'abstract': 0,
#      'title': 'Emerging infections and their causative agents'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9Rn1sXEBuCitufzFv2uI',
#     '_score': 1.5973129,
#     '_source': {'abstract': 0, 'title': 'Volume 127 - Contents'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ihn1sXEBuCitufzFn2Wo',
#     '_score': 1.5973037,
#     '_source': {'abstract': 0, 'title': 'Sequences and topology'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Chn1sXEBuCitufzFp2fb',
#     '_score': 1.5970455,
#     '_source': {'abstract': 'Unknown', 'title': 'Glossary and Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ixn1sXEBuCitufzFn2Wo',
#     '_score': 1.5969772,
#     '_source': {'abstract': 0, 'title': 'Membrane proteins'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'bRn4sXEBuCitufzF6ssr',
#     '_score': 1.5968866,
#     '_source': {'abstract': 0, 'title': 'Technology and public health'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lBn1sXEBuCitufzFn2Wo',
#     '_score': 1.5967786,
#     '_source': {'abstract': 0, 'title': 'SH2 and SH3 domains'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Jxn1sXEBuCitufzFm2Qq',
#     '_score': 1.5966856,
#     '_source': {'abstract': 0, 'title': 'Contents of Volume 19'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '2Rn3sXEBuCitufzFJZYM',
#     '_score': 1.596574,
#     '_source': {'abstract': 0, 'title': 'New Product Developments'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'YxnzsXEBuCitufzFfimx',
#     '_score': 1.5964878,
#     '_source': {'abstract': 0,
#      'title': 'Comment on “Gain-of-Function Research and the Relevance to Clinical Practice”'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'DRnzsXEBuCitufzFKCDT',
#     '_score': 1.5964768,
#     '_source': {'abstract': 0, 'title': 'ACE in the hole'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '6xn3sXEBuCitufzFLZe3',
#     '_score': 1.596475,
#     '_source': {'abstract': 0,
#      'title': 'Tratamiento del catarro. Evidencia científica'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oRn0sXEBuCitufzFfEN4',
#     '_score': 1.5962963,
#     '_source': {'abstract': 0, 'title': 'One world – one health'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'pBn1sXEBuCitufzFmWMk',
#     '_score': 1.5962931,
#     '_source': {'abstract': 0, 'title': 'Subject index for volume 157'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'qhn2sXEBuCitufzF-pEw',
#     '_score': 1.5960999,
#     '_source': {'abstract': 0, 'title': 'Emerging viral infections'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SBn1sXEBuCitufzFrGj9',
#     '_score': 1.596007,
#     '_source': {'abstract': 0, 'title': 'Chapter 1 Introduction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Txn1sXEBuCitufzFrGj9',
#     '_score': 1.596007,
#     '_source': {'abstract': 0, 'title': 'Chapter 1 Introduction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Whn1sXEBuCitufzFrGj9',
#     '_score': 1.596007,
#     '_source': {'abstract': 0, 'title': 'Chapter 1 Introduction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'kBn4sXEBuCitufzFg7-u',
#     '_score': 1.5960069,
#     '_source': {'abstract': 0, 'title': 'CHAPTER 1 Introduction'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_xn1sXEBuCitufzFp2bb',
#     '_score': 1.5957721,
#     '_source': {'abstract': 'Unknown', 'title': 'Acronyms and Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'chn1sXEBuCitufzFpGa_',
#     '_score': 1.5957721,
#     '_source': {'abstract': 'Unknown', 'title': 'Acronyms and Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oBn1sXEBuCitufzFpGa_',
#     '_score': 1.5957721,
#     '_source': {'abstract': 'Unknown', 'title': 'Acronyms and Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'oRn1sXEBuCitufzFl2Nm',
#     '_score': 1.5956565,
#     '_source': {'abstract': 0, 'title': 'Subject index for volume 151'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '-Rn1sXEBuCitufzFSlkr',
#     '_score': 1.5951513,
#     '_source': {'abstract': 0, 'title': 'News Briefs'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_Rn1sXEBuCitufzFr2gq',
#     '_score': 1.5951513,
#     '_source': {'abstract': 0, 'title': 'News Briefs'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '_hn1sXEBuCitufzFr2gq',
#     '_score': 1.5951513,
#     '_source': {'abstract': 0, 'title': 'News Briefs'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'ABn1sXEBuCitufzFr2kq',
#     '_score': 1.5951512,
#     '_source': {'abstract': 0, 'title': 'News Briefs'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'fxn1sXEBuCitufzFHVS_',
#     '_score': 1.5950385,
#     '_source': {'abstract': 0, 'title': 'Asthma'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Bhn1sXEBuCitufzF6HSq',
#     '_score': 1.5949211,
#     '_source': {'abstract': 0, 'title': 'Are We Ready for Anything?'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9Rn4sXEBuCitufzFbrzk',
#     '_score': 1.5947111,
#     '_source': {'abstract': 0, 'title': 'Offline: Facts are not enough'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn1sXEBuCitufzFU1vj',
#     '_score': 1.5946163,
#     '_source': {'abstract': 0,
#      'title': 'Principles and Practice of Clinical Virology'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn1sXEBuCitufzFl2Nm',
#     '_score': 1.5944718,
#     '_source': {'abstract': 0, 'title': 'Subject index to volume 87'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'sxnzsXEBuCitufzFaSbk',
#     '_score': 1.5942465,
#     '_source': {'abstract': 0, 'title': 'ISNV Meeting Supplement'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'SBnysXEBuCitufzFIAdu',
#     '_score': 1.5940237,
#     '_source': {'abstract': 0, 'title': 'Chances and challenges in China'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Oxn0sXEBuCitufzFCjh_',
#     '_score': 1.5938869,
#     '_source': {'abstract': 0, 'title': 'Vigorous controls minimise risk'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'VRn1sXEBuCitufzFBlFH',
#     '_score': 1.5934758,
#     '_source': {'abstract': 0, 'title': 'News updates'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'JBn1sXEBuCitufzFm2Qq',
#     '_score': 1.5930877,
#     '_source': {'abstract': 0, 'title': 'Contents to volume 14'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'lhn1sXEBuCitufzFl2Nm',
#     '_score': 1.5927875,
#     '_source': {'abstract': 0, 'title': 'Subject index for volume 108'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dxn2sXEBuCitufzFzYyU',
#     '_score': 1.5927625,
#     '_source': {'abstract': 0, 'title': 'My experience with SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KBn1sXEBuCitufzFRlm4',
#     '_score': 1.592308,
#     '_source': {'abstract': 0, 'title': 'SARS: seeking a real-time solution'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'jRn1sXEBuCitufzFQFg_',
#     '_score': 1.5918193,
#     '_source': {'abstract': 0, 'title': 'Pneumonias'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'RRn1sXEBuCitufzFn2Wo',
#     '_score': 1.5914677,
#     '_source': {'abstract': 0, 'title': 'Subject index to volume 5'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'uRn1sXEBuCitufzF2XBE',
#     '_score': 1.5910683,
#     '_source': {'abstract': 0, 'title': 'Index to Volume 19'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4hn1sXEBuCitufzFv2uI',
#     '_score': 1.5910131,
#     '_source': {'abstract': 0, 'title': 'Author index of volume 166'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'TBn4sXEBuCitufzFncKr',
#     '_score': 1.5908736,
#     '_source': {'abstract': 0, 'title': '8 Passerines'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vBn1sXEBuCitufzFr2gq',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8hn1sXEBuCitufzFoWXn',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rhn1sXEBuCitufzFp2bb',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'FBn1sXEBuCitufzFp2fb',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of Abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'PRn1sXEBuCitufzFqmcy',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'uxn1sXEBuCitufzFr2gq',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'vRn1sXEBuCitufzFr2gq',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'zhn1sXEBuCitufzFr2gq',
#     '_score': 1.5907934,
#     '_source': {'abstract': 'Unknown', 'title': 'List of abbreviations'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '1Bn1sXEBuCitufzFoWXn',
#     '_score': 1.5906513,
#     '_source': {'abstract': 0,
#      'title': '(a) Infections and Medical Diseases'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'VRn1sXEBuCitufzFx20H',
#     '_score': 1.5906377,
#     '_source': {'abstract': 0, 'title': 'Keywords index'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'dBn2sXEBuCitufzF9ZHP',
#     '_score': 1.5905493,
#     '_source': {'abstract': 0, 'title': 'I. Anaesthesia and SARS'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'tBn1sXEBuCitufzFv2uI',
#     '_score': 1.5903167,
#     '_source': {'abstract': 0, 'title': 'Volume Contents Index'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'nxn4sXEBuCitufzFHbPD',
#     '_score': 1.5901663,
#     '_source': {'abstract': 0, 'title': 'III Fiches maladies'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'Kxn1sXEBuCitufzFm2Qq',
#     '_score': 1.590046,
#     '_source': {'abstract': 0, 'title': 'Contents volume 43'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '8Rn1sXEBuCitufzFmWMk',
#     '_score': 1.5898392,
#     '_source': {'abstract': 0, 'title': 'Subject index (vol. 6)'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '4Rn3sXEBuCitufzFsKbj',
#     '_score': 1.5896189,
#     '_source': {'abstract': 0, 'title': 'Antiviral Agents'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'rRn0sXEBuCitufzFQz0-',
#     '_score': 1.5895705,
#     '_source': {'abstract': 0, 'title': 'Democracy and health'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': '9hn1sXEBuCitufzFq2e0',
#     '_score': 1.5892695,
#     '_source': {'abstract': 0,
#      'title': '2 STRUCTURE OF THE RESPIRATORY SYSTEM, RELATED TO FUNCTION'}},
#    {'_index': 'covid',
#     '_type': '_doc',
#     '_id': 'KRn1sXEBuCitufzFm2Qq',
#     '_score': 1.5891434,
#     '_source': {'abstract': 0, 'title': 'Contents of volume 29'}}]}}
